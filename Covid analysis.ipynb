# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/WidhyaOrg/datasets/master/covid19.csv')

# %%
df
# Out:
#      Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0      1  30/01/20               Kerala                        1
# 1      2  31/01/20               Kerala                        1
# 2      3  01/02/20               Kerala                        2
# 3      4  02/02/20               Kerala                        3
# 4      5  03/02/20               Kerala                        3
# ..   ...       ...                  ...                      ...
# 265  266  21/03/20    Jammu and Kashmir                        4
# 266  267  21/03/20               Ladakh                       13
# 267  268  21/03/20        Uttar Pradesh                       23
# 268  269  21/03/20          Uttarakhand                        3
# 269  270  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# 2                           0      0       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       270 non-null    int64
#  1   Date                      270 non-null    object
#  2   State/UnionTerritory      270 non-null    object
#  3   ConfirmedIndianNational   270 non-null    int64
#  4   ConfirmedForeignNational  270 non-null    int64
#  5   Cured                     270 non-null    int64
#  6   Deaths                    270 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 14.9+ KB

# %%
df = df.drop(columns = ['Sno', 'State/UnionTerritory'])

# %%
df
# Out:
#          Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 0    30/01/20                        1                         0      0
# 1    31/01/20                        1                         0      0
# 2    01/02/20                        2                         0      0
# 3    02/02/20                        3                         0      0
# 4    03/02/20                        3                         0      0
# ..        ...                      ...                       ...    ...
# 265  21/03/20                        4                         0      0
# 266  21/03/20                       13                         0      0
# 267  21/03/20                       23                         1      9
# 268  21/03/20                        3                         0      0
# 269  21/03/20                        3                         0      0
#
#      Deaths
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# ...

# %%
df1 = df.groupby(df['Date'], sort = False).sum()

# %%
df1
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 30/01/20 to 21/03/20
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ConfirmedIndianNational   52 non-null     int64
#  1   ConfirmedForeignNational  52 non-null     int64
#  2   Cured                     52 non-null     int64
#  3   Deaths                    52 non-null     int64
# dtypes: int64(4)
# memory usage: 2.0+ KB

# %%
df1['total'] = df1.sum(axis = 1)

# %%
df1
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
df1 = df1.reset_index()

# %%
df1
# Out:
#         Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 0   30/01/20                        1                         0      0
# 1   31/01/20                        1                         0      0
# 2   01/02/20                        2                         0      0
# 3   02/02/20                        3                         0      0
# 4   03/02/20                        3                         0      0
# 5   04/02/20                        3                         0      0
# 6   05/02/20                        3                         0      0
# 7   06/02/20                        3                         0      0
# 8   07/02/20                        3                         0      0
# 9   08/02/20                        3                         0      0
# 10  09/02/20                        3                         0      0
# 11  10/02/20                        3                         0      0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      52 non-null     object
#  1   ConfirmedIndianNational   52 non-null     int64
#  2   ConfirmedForeignNational  52 non-null     int64
#  3   Cured                     52 non-null     int64
#  4   Deaths                    52 non-null     int64
#  5   total                     52 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.6+ KB

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df1['Date'], df1['total'])
plt.xlabel('Date')
plt.ylabel('Total cases')
plt.show()

# %%
r = (((33-31)/31)+((34-33)/33)+((37-34)/34)+((42-37)/37)+((49-42)/42)+((61-49)/49)+((63-61)/61)+((77-63)/63)+((85-77)/77)+((96-85)/85)+((125-96)/96)+((129-125)/125)+((154-129)/129)+((168-154)/154)+((197-168)/168)+((250-197)/197)+((310-250)/250))/17

# %%
r
# Out:
# 0.14814803793984233

# %%
p_t = 31*47.080033146394925

# %%
import math

# %%
math.exp(r*26)
# Out:
# 47.080033146394925

# %%
p_t
# Out:
# 1459.4810275382426
